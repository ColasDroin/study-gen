# %%
from study_gen import StudyGen
from blocks import dict_ref_blocks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 from study_gen import StudyGen
# ----> 2 from blocks import dict_ref_blocks
#
# File ~/Documents/study-gen/prototyping/collider_from_mad/blocks/__init__.py:10
#       7 module_name = "_".join(module.split("_")[1:])[:-3]
#       8 module_filename = module[:-3]
#       9 dict_ref_blocks[module_name] = getattr(
# ---> 10     __import__(f"blocks.{module_filename}", fromlist=[module_filename]),
#      11     module_name,
#      12 )
#
# File ~/Documents/study-gen/prototyping/collider_from_mad/blocks/b100_prepare_mad_environment.py:50
#      43     return sequence_name_b1, sequence_name_b2, mad_b1b2, sequence_name_b4, mad_b4
#      46 # ==================================================================================================
#      47 # --- Block object ---
#      48 # ==================================================================================================
# ---> 50 prepare_mad_environment = Block(
#      51     "prepare_mad_environment",
#      52     prepare_mad_environment_function,
#      53     dict_imports=dict_imports,
#      54     dict_output=OrderedDict([("output_prepare_mad_environment", tuple[str, str, Madx, str, Madx])]),
#      55 )
#
# File ~/Documents/study-gen/study_gen/block.py:24, in Block.__init__(self, name, function, dict_imports, set_deps, dict_output)
#      22 self.set_deps = set_deps
#      23 self._l_arguments = []
# ---> 24 self.initial_dic_output_setter(dict_output)
#
# File ~/Documents/study-gen/study_gen/block.py:69, in Block.initial_dic_output_setter(self, dict_output)
#      65 if "tuple[" in signature_output_str:
#      66
#      67     # Check that the number of outputs is the same
#      68     if len(dict_output) != len(signature_type_hint.__args__): # type: ignore
# ---> 69         raise ValueError(
#      70             f"Number of outputs differs from type hint signature for block {self.name}."
#      71         )
#      73     # Check that the provided output(s) have the correct type
#      74     if signature_type_hint is not None:
#      75         # Compare the signature type hint of each output (unpacked) with the provided output type hints
#
# ValueError: Number of outputs differs from type hint signature for block prepare_mad_environment.

# %%
study = StudyGen(path_configuration='config.yaml', path_master='master.yaml', dict_ref_blocks = dict_ref_blocks)

# %%
l_gen = study.generate_all()
for gen in l_gen:
    print(gen)
# Out:
# prepare_mad_environment
# ['links']
# OrderedDict({'sequence_name_b1': <class 'cpymad.madx.Madx'>})
# /n
# build_hllhc_sequence
# ['sequence_name_b1', 'mad_b1b2', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC']
# OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>})
# /n
# build_hllhc_sequence
# ['sequence_name_b4', 'mad_b4', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC']
# OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>})
# /n
# apply_optics
# ['mad_b1b2', 'optics_file']
# OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>})
# /n
# check_madx_lattice
# ['mad_b1b2', 'sequence_name_b1']
# OrderedDict()
# /n
# check_madx_lattice
# ['mad_b1b2', 'sequence_name_b2']
# OrderedDict()
# /n
# apply_optics
# ['mad_b4', 'optics_file']
# OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>})
# /n
# check_madx_lattice
# ['mad_b4', 'sequence_name_b2']
# OrderedDict()
# /n
# build_collider
# ['mad_b1b2', 'mad_b4', 'beam_config', 'enable_imperfections', 'enable_knob_synthesis', 'rename_coupling_knobs', 'pars_for_imperfections', 'ver_hllhc_optics']
# OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# /n
# build_trackers
# ['collider']
# OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# /n
# check_xsuite_twiss
# ['collider']
# OrderedDict()
# /n
# activate_RF
# ['collider']
# OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# /n
# display_xsuite_lattice
# ['collider']
# OrderedDict()
# /n
# clean_temp_files
# []
# OrderedDict()
# /n
# dump_collider_json
# ['collider']
# OrderedDict({'name_base_collider': <class 'str'>})
# /n
# OrderedDict({'links': <class 'collections.OrderedDict'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>, 'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>, 'sequence_name_b2': <class 'str'>, 'beam_config': <class 'collections.OrderedDict'>, 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': <class 'collections.OrderedDict'>, 'ver_hllhc_optics': <class 'float'>})
# OrderedDict({'links': <class 'collections.OrderedDict'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>, 'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>, 'sequence_name_b2': <class 'str'>, 'beam_config': <class 'collections.OrderedDict'>, 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': <class 'collections.OrderedDict'>, 'ver_hllhc_optics': <class 'float'>})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 l_gen = study.generate_all()
#       2 for gen in l_gen:
#       3     print(gen)
#
# File ~/Documents/study-gen/study_gen/study_gen.py:336, in StudyGen.generate_all(self)
#     334 for gen in sorted(self.master.keys()):
#     335     file_path_gen = f"{gen}.py"
# --> 336     str_imports, str_parameters, str_blocks, str_main, str_main_call = self.generate_gen(
#     337         gen
#     338     )
#     339     study_str = self.render(
#     340         str_imports, str_parameters, str_blocks, str_main, str_main_call
#     341     )
#     342     self.write(study_str, file_path_gen)
#
# File ~/Documents/study-gen/study_gen/study_gen.py:286, in StudyGen.generate_gen(self, gen)
#     283 main_block = self.generate_main_block(gen, dict_blocks)
#     285 # Declare parameters
# --> 286 str_parameters = self.get_parameters_assignation(main_block)
#     288 # Get main block string
#     289 str_main = main_block.get_str()
#
# File ~/Documents/study-gen/study_gen/study_gen.py:258, in StudyGen.get_parameters_assignation(self, main_block)
#     256 value = _finditem(self.configuration, param)
#     257 if value is None:
# --> 258     raise ValueError(f"Parameter {param} is not defined in the configuration")
#     259 if isinstance(value, str):
#     260     value = f'"{value}"'
#
# ValueError: Parameter mad_b1b2 is not defined in the configuration

# %%
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/macbe16879/Desktop/study-gen/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
