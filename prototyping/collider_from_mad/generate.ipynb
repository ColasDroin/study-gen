# %%
from study_gen import StudyGen
from blocks import dict_ref_blocks
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/macbe16879/Desktop/study-gen/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
study = StudyGen(path_configuration='config.yaml', path_master='master.yaml', dict_ref_blocks = dict_ref_blocks)

# %%
l_gen = study.generate_all()
for gen in l_gen:
    print(gen)
# Out:
# block1 prepare_mad_environment
# block2 build_hllhc_sequence
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# block1 prepare_mad_environment
# block2 build_hllhc_sequence
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# block1 prepare_mad_environment
# block2 apply_optics
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 prepare_mad_environment
# block2 check_madx_lattice
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# block1 prepare_mad_environment
# block2 check_madx_lattice
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 prepare_mad_environment
# block2 apply_optics
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 prepare_mad_environment
# block2 check_madx_lattice
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 prepare_mad_environment
# block2 build_collider
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 prepare_mad_environment
# block2 build_trackers
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 prepare_mad_environment
# block2 check_xsuite_twiss
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 prepare_mad_environment
# block2 activate_RF
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 prepare_mad_environment
# block2 display_xsuite_lattice
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 prepare_mad_environment
# block2 clean_temp_files
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict()
# block1 prepare_mad_environment
# block2 dump_collider_json
# args block1 OrderedDict({'links': collections.OrderedDict[str, typing.Any]})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 build_hllhc_sequence
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# block1 build_hllhc_sequence
# block2 apply_optics
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 apply_optics
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 build_collider
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 build_hllhc_sequence
# block2 build_trackers
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 check_xsuite_twiss
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 activate_RF
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 display_xsuite_lattice
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 clean_temp_files
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict()
# block1 build_hllhc_sequence
# block2 dump_collider_json
# args block1 OrderedDict({'sequence_name_b1': <class 'str'>, 'mad_b1b2': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 apply_optics
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 apply_optics
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 build_hllhc_sequence
# block2 check_madx_lattice
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 build_hllhc_sequence
# block2 build_collider
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 build_hllhc_sequence
# block2 build_trackers
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 check_xsuite_twiss
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 activate_RF
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 display_xsuite_lattice
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_hllhc_sequence
# block2 clean_temp_files
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict()
# block1 build_hllhc_sequence
# block2 dump_collider_json
# args block1 OrderedDict({'sequence_name_b4': <class 'str'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'apply_acsca_fix': <class 'bool'>, 'cycle_to_IP3': <class 'bool'>, 'incorporate_CC': <class 'bool'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# block1 apply_optics
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 apply_optics
# block2 apply_optics
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 apply_optics
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 apply_optics
# block2 build_collider
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 apply_optics
# block2 build_trackers
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 activate_RF
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict()
# block1 apply_optics
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 check_madx_lattice
# block2 apply_optics
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 check_madx_lattice
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 check_madx_lattice
# block2 build_collider
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 check_madx_lattice
# block2 build_trackers
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 activate_RF
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict()
# block1 check_madx_lattice
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b1b2, sequence_name_b1': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 apply_optics
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# block1 check_madx_lattice
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 check_madx_lattice
# block2 build_collider
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 check_madx_lattice
# block2 build_trackers
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 activate_RF
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict()
# block1 check_madx_lattice
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b1b2, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 check_madx_lattice
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# block1 apply_optics
# block2 build_collider
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 apply_optics
# block2 build_trackers
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 activate_RF
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 apply_optics
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict()
# block1 apply_optics
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b4': <class 'cpymad.madx.Madx'>, 'optics_file': <class 'str'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 build_collider
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# block1 check_madx_lattice
# block2 build_trackers
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 activate_RF
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_madx_lattice
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict()
# block1 check_madx_lattice
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b4, sequence_name_b2': <class 'cpymad.madx.Madx'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_collider
# block2 build_trackers
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_collider
# block2 check_xsuite_twiss
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_collider
# block2 activate_RF
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_collider
# block2 display_xsuite_lattice
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_collider
# block2 clean_temp_files
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict()
# block1 build_collider
# block2 dump_collider_json
# args block1 OrderedDict({'mad_b1b2': <class 'cpymad.madx.Madx'>, 'mad_b4': <class 'cpymad.madx.Madx'>, 'beam_config': collections.OrderedDict[str, typing.Any], 'enable_imperfections': <class 'bool'>, 'enable_knob_synthesis': <class 'bool'>, 'rename_coupling_knobs': <class 'bool'>, 'pars_for_imperfections': collections.OrderedDict[str, int], 'ver_hllhc_optics': <class 'float'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_trackers
# block2 check_xsuite_twiss
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_trackers
# block2 activate_RF
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_trackers
# block2 display_xsuite_lattice
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 build_trackers
# block2 clean_temp_files
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict()
# block1 build_trackers
# block2 dump_collider_json
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_xsuite_twiss
# block2 activate_RF
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_xsuite_twiss
# block2 display_xsuite_lattice
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 check_xsuite_twiss
# block2 clean_temp_files
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict()
# block1 check_xsuite_twiss
# block2 dump_collider_json
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 activate_RF
# block2 display_xsuite_lattice
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 activate_RF
# block2 clean_temp_files
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict()
# block1 activate_RF
# block2 dump_collider_json
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 display_xsuite_lattice
# block2 clean_temp_files
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict()
# block1 display_xsuite_lattice
# block2 dump_collider_json
# args block1 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# block1 clean_temp_files
# block2 dump_collider_json
# args block1 OrderedDict()
# args block2 OrderedDict({'collider': <class 'xtrack.multiline.multiline.Multiline'>})
# Traceback (most recent call last):
#
#   File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     l_gen = study.generate_all()
#
#   File ~/Desktop/study-gen/study_gen/study_gen.py:329 in generate_all
#     str_imports, str_parameters, str_blocks, str_main, str_main_call = self.generate_gen(
#
#   File ~/Desktop/study-gen/study_gen/study_gen.py:276 in generate_gen
#     main_block = self.generate_main_block(gen, dict_blocks)
#
#   File ~/Desktop/study-gen/study_gen/study_gen.py:227 in generate_main_block
#     main_block = self.build_merged_blocks(
#
#   File ~/Desktop/study-gen/study_gen/study_gen.py:149 in build_merged_blocks
#     new_block_function = merge.merge_blocks(
#
#   File ~/Desktop/study-gen/study_gen/merge/merge.py:42 in merge_blocks
#     function = Block.write_and_load_temp_block(function_str, name_merged_function, dict_imports)
#
#   File ~/Desktop/study-gen/study_gen/block.py:376 in write_and_load_temp_block
#     spec.loader.exec_module(mod)
#
#   File <frozen importlib._bootstrap_external>:990 in exec_module
#
#   File <frozen importlib._bootstrap_external>:1128 in get_code
#
#   File <frozen importlib._bootstrap_external>:1058 in source_to_code
#
#   File <frozen importlib._bootstrap>:488 in _call_with_frames_removed
#
#   File /var/folders/jq/hz3435357pz99qz4s0s1wvl00000gn/T/tmpzqqdin6q.py:7
#     def main(links: OrderedDict, sequence_name_b1: str, mad_b1b2: Madx, apply_acsca_fix: bool, cycle_to_IP3: bool, incorporate_CC: bool, sequence_name_b4: str, mad_b4: Madx, optics_file: str, mad_b1b2, sequence_name_b1: Madx, mad_b1b2, sequence_name_b2: Madx, mad_b4, sequence_name_b2: Madx, beam_config: OrderedDict, enable_imperfections: bool, enable_knob_synthesis: bool, rename_coupling_knobs: bool, pars_for_imperfections: OrderedDict, ver_hllhc_optics: float) -> None:
#                                                                                                                                                                                                 ^
# SyntaxError: duplicate argument 'mad_b1b2' in function definition

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
