# %%
from study_gen import StudyGen
from blocks import dict_ref_blocks

# %%
study = StudyGen(path_configuration='config.yaml', path_master='master.yaml', dict_ref_blocks = dict_ref_blocks)
# Out:
# It seems that you have duplicate keys in your master file. Please ensure that no block is being called twice with the same name in a given scope. If that's the case, please append '__x' to the end of the block name, where x corresponds to the xth repetition of the block.
# while constructing a mapping
#   in "master.yaml", line 4, column 5
# found duplicate key "build_hllhc_sequence" with value "{'args': ['sequence_name_b4', 'mad_b4', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC'], 'output': 'mad_b4'}" (original value: "{'args': ['sequence_name_b1', 'mad_b1b2', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC'], 'output': 'mad_b1b2'}")
#   in "master.yaml", line 10, column 5
#
# To suppress this check see:
#     http://yaml.readthedocs.io/en/latest/api.html#duplicate-keys
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# File ~/Desktop/study-gen/study_gen/study_gen.py:37, in StudyGen.load_master(self, path_master)
#      36 try:
# ---> 37     master = ryaml.load(f)
#      38 except yaml.YAMLError as e:
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/main.py:451, in YAML.load(self, stream)
#     450 try:
# --> 451     return constructor.get_single_data()
#     452 finally:
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:114, in BaseConstructor.get_single_data(self)
#     113 if node is not None:
# --> 114     return self.construct_document(node)
#     115 return None
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:123, in BaseConstructor.construct_document(self, node)
#     122 for generator in state_generators:
# --> 123     for _dummy in generator:
#     124         pass
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1470, in RoundTripConstructor.construct_yaml_map(self, node)
#    1469 yield data
# -> 1470 self.construct_mapping(node, data, deep=True)
#    1471 self.set_collection_style(data, node)
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1359, in RoundTripConstructor.construct_mapping(self, node, maptyp, deep)
#    1353     raise ConstructorError(
#    1354         'while constructing a mapping',
#    1355         node.start_mark,
#    1356         'found unhashable key',
#    1357         key_node.start_mark,
#    1358     )
# -> 1359 value = self.construct_object(value_node, deep=deep)
#    1360 if self.check_mapping_key(node, key_node, maptyp, key, value):
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:145, in BaseConstructor.construct_object(self, node, deep)
#     144 self.recursive_objects[node] = None
# --> 145 data = self.construct_non_recursive_object(node)
#     147 self.constructed_objects[node] = data
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:186, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     185 if self.deep_construct:
# --> 186     for _dummy in generator:
#     187         pass
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1470, in RoundTripConstructor.construct_yaml_map(self, node)
#    1469 yield data
# -> 1470 self.construct_mapping(node, data, deep=True)
#    1471 self.set_collection_style(data, node)
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1359, in RoundTripConstructor.construct_mapping(self, node, maptyp, deep)
#    1353     raise ConstructorError(
#    1354         'while constructing a mapping',
#    1355         node.start_mark,
#    1356         'found unhashable key',
#    1357         key_node.start_mark,
#    1358     )
# -> 1359 value = self.construct_object(value_node, deep=deep)
#    1360 if self.check_mapping_key(node, key_node, maptyp, key, value):
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:145, in BaseConstructor.construct_object(self, node, deep)
#     144 self.recursive_objects[node] = None
# --> 145 data = self.construct_non_recursive_object(node)
#     147 self.constructed_objects[node] = data
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:186, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     185 if self.deep_construct:
# --> 186     for _dummy in generator:
#     187         pass
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1470, in RoundTripConstructor.construct_yaml_map(self, node)
#    1469 yield data
# -> 1470 self.construct_mapping(node, data, deep=True)
#    1471 self.set_collection_style(data, node)
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:1360, in RoundTripConstructor.construct_mapping(self, node, maptyp, deep)
#    1359 value = self.construct_object(value_node, deep=deep)
# -> 1360 if self.check_mapping_key(node, key_node, maptyp, key, value):
#    1361     if self.loader and self.loader.comment_handling is None:
#
# File ~/Desktop/study-gen/.venv/lib/python3.12/site-packages/ruamel/yaml/constructor.py:276, in BaseConstructor.check_mapping_key(self, node, key_node, mapping, key, value)
#     275     else:
# --> 276         raise DuplicateKeyError(*args)
#     277 return False
#
# DuplicateKeyError: while constructing a mapping
#   in "master.yaml", line 4, column 5
# found duplicate key "build_hllhc_sequence" with value "{'args': ['sequence_name_b4', 'mad_b4', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC'], 'output': 'mad_b4'}" (original value: "{'args': ['sequence_name_b1', 'mad_b1b2', 'apply_acsca_fix', 'cycle_to_IP3', 'incorporate_CC'], 'output': 'mad_b1b2'}")
#   in "master.yaml", line 10, column 5
#
# To suppress this check see:
#     http://yaml.readthedocs.io/en/latest/api.html#duplicate-keys
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 study = StudyGen(path_configuration='config.yaml', path_master='master.yaml', dict_ref_blocks = dict_ref_blocks)
#
# File ~/Desktop/study-gen/study_gen/study_gen.py:22, in StudyGen.__init__(self, path_configuration, path_master, dict_ref_blocks, path_template, template_name)
#      13 def __init__(
#      14     self: Self,
#      15     path_configuration: str,
#    (...)
#      19     template_name: str = "default_template.txt",
#      20 ):
#      21     self.configuration = self.load_configuration(path_configuration)
# ---> 22     self.master = self.load_master(path_master)
#      23     self.path_template = path_template
#      24     self.template_name = template_name
#
# File ~/Desktop/study-gen/study_gen/study_gen.py:46, in StudyGen.load_master(self, path_master)
#      39         print(
#      40             "It seems that you have duplicate keys in your master file. Please ensure that"
#      41             " no block is being called twice with the same name in a given scope. If that's"
#      42             " the case, please append '__x' to the end of the block name, where x"
#      43             " corresponds to the xth repetition of the block."
#      44         )
#      45         print(e)
# ---> 46         exit(1)
#      47 return master
#
# NameError: name 'exit' is not defined

# %%
l_gen = study.generate_all()
for gen in l_gen:
    print(gen)
# Out:
# # ==================================================================================================
# # --- Imports
# # ==================================================================================================
#
# import numpy as np
# import itertools
# import os
# import pandas as pd
#
# # ==================================================================================================
# # --- Blocks
# # ==================================================================================================
#
# def build_distribution_function(
#     r_min: float, r_max: float, n_r: int, n_angles: int, n_split: int
# ) -> list[list[tuple[int, float, float]]]:
#     radial_list = np.linspace(r_min, r_max, n_r, endpoint=False)
#
#     # Define angle distribution
#     theta_list = np.linspace(0, 90, n_angles + 2)[1:-1]
#
#     # Define particle distribution as a cartesian product of the above
#     particle_list = [
#         (particle_id, ii[1], ii[0])
#         for particle_id, ii in enumerate(itertools.product(theta_list, radial_list))
#     ]
#
#     # Split distribution into several chunks for parallelization
#     particle_list = list(np.array_split(particle_list, n_split))
#
#     # Return distribution
#     return particle_list
#
# def write_distribution_function(particle_list: list[list[tuple[int, float, float]]]) -> None:
#     # Write distribution to parquet files
#     distributions_folder = "particles"
#     os.makedirs(distributions_folder, exist_ok=True)
#     for idx_chunk, my_list in enumerate(particle_list):
#         pd.DataFrame(
#             my_list,
#             columns=["particle_id", "normalized amplitude in xy-plane", "angle in xy-plane [deg]"],
#         ).to_parquet(f"{distributions_folder}/{idx_chunk:02}.parquet")
#
#
# # ==================================================================================================
# # --- Main
# # ==================================================================================================
#
# def main(r_min: float, r_max: float, n_r: int, n_angles: int, n_split: int) -> None:
#
#     particle_list = build_distribution_function(r_min, r_max, n_r, n_angles, n_split)
#     write_distribution_function(particle_list)
#
#
#
# # ==================================================================================================
# # --- Parameters
# # ==================================================================================================
#
# # Declare parameters
# r_min = 2.0
# r_max = 10.0
# n_r = 256
# n_angles = 5
# n_split = 15
#
#
# # ==================================================================================================
# # --- Script
# # ==================================================================================================
#
# if __name__ == "__main__":
#     main(r_min, r_max, n_r, n_angles, n_split)
