# %%
from study_gen import StudyGen
from blocks import dict_ref_blocks

# %%
study = StudyGen(path_configuration='config.yaml', path_master='master.yaml', dict_ref_blocks = dict_ref_blocks)

# %%
l_gen = study.generate_all()
for gen in l_gen:
    print(gen)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 l_gen = study.generate_all()
#       2 for gen in l_gen:
#       3     print(gen)
#
# File ~/Documents/study-gen/study_gen/study_gen.py:333, in StudyGen.generate_all(self)
#     331 for gen in sorted(self.master.keys()):
#     332     file_path_gen = f"{gen}.py"
# --> 333     str_imports, str_parameters, str_blocks, str_main, str_main_call = self.generate_gen(
#     334         gen
#     335     )
#     336     study_str = self.render(
#     337         str_imports, str_parameters, str_blocks, str_main, str_main_call
#     338     )
#     339     self.write(study_str, file_path_gen)
#
# File ~/Documents/study-gen/study_gen/study_gen.py:280, in StudyGen.generate_gen(self, gen)
#     275     dict_blocks = self.incorporate_merged_blocks(
#     276         self.master[gen]["new_blocks"], dict_blocks
#     277     )
#     279 # Add main as ultimate block
# --> 280 main_block = self.generate_main_block(gen, dict_blocks)
#     282 # Declare parameters
#     283 str_parameters = self.get_parameters_assignation(main_block)
#
# File ~/Documents/study-gen/study_gen/study_gen.py:231, in StudyGen.generate_main_block(self, gen, dict_blocks)
#     228 # Convert script format to new_block format
#     229 main_block_dict = OrderedDict([(str("blocks"), script)])
# --> 231 main_block = self.build_merged_blocks(
#     232     new_block_name="main",
#     233     new_block=main_block_dict,
#     234     dict_blocks=dict_blocks,
#     235     name_merged_function="main",
#     236 )
#     238 return main_block
#
# File ~/Documents/study-gen/study_gen/study_gen.py:117, in StudyGen.build_merged_blocks(self, new_block_name, new_block, dict_blocks, name_merged_function)
#     115 # Get outputs
#     116 l_outputs = new_block["blocks"][block]["output"]
# --> 117 block_to_update.set_outputs_names(l_outputs)
#     119 # Add to updated list of blocks
#     120 l_blocks.append(block_to_update)
#
# File ~/Documents/study-gen/study_gen/block.py:69, in Block.set_outputs_names(self, l_outputs_names)
#      65 def set_outputs_names(self: Self, l_outputs_names: list[str]):
#      66     # Ensure that l_outputs_names is not just a string
#      67     if not isinstance(l_outputs_names, list):
#      68         # Ensure the user did not provide a string with a comma
# ---> 69         if "," in l_outputs_names:
#      70             l_outputs_names = l_outputs_names.split(",")
#      71         else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/macbe16879/Desktop/study-gen/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
